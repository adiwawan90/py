# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ## Soal 1
# Dari data x dan y buatlah sebuah figure dengan ketentuan :
# 1. Judul figure adalah Data Penjualan PT. Sejahtera
# 2. X label adalah Pembelian
# 3. Y label adalah penjualan

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel('Pembelian')
axes.set_ylabel('Penjualan')
axes.set_title('Data Penjualan PT.Sejahtera')
# Out:
# Text(0.5, 1.0, 'Data Penjualan PT.Sejahtera')

# %% [markdown]
# ## Soal 2
#
# Buatlah sebuah figure dengan ketentuan :
# 1. menggunakan 2 axes
# 2. ax1 adalah [0,0,1,1] dan ax2 adalah [0.2,0.5,.2,.2]

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])

# %% [markdown]
# sekarang isi data dari masing - masing axes tersebut dengan x dan y

# %%
ax1.plot(x,y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2.plot(x,y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
fig

# %% [markdown]
# ## Soal 3
#
# Buatlah sebuah figure dengan ketentuan :
# 1. Menggunakan sub plot 1 baris 2 kolom

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# 2. Sekarang isi data plot pertama dengan data x dan y dan buat sesuai dengan tampilan di bawah
# 3. Sekarang isi data plot pertama dengan data x dan z dan buat sesuai dengan tampilan di bawah

# %%
axes[0].plot(x,y,color="blue", lw=3, ls='-',marker='$...$')
axes[1].plot(x,z,color="yellow",lw=3,ls='-',marker='*',markeredgewidth=1, markerfacecolor='blue', markeredgecolor='green')
fig

# %% [markdown]
# # Buat tampilannya menjadi seperti ini

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12,2))

axes[0].plot(x,y,color="blue", lw=3,ls='-',marker='$...$')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x,z,color="blue", lw=3, ls='-',marker='*')
axes[1].set_xlabel('x')
axes[1].set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# # Final Soal
#
# buatlah histogram plot dari 100 data random 1 - 5000 dan jelaskan tentang plot itu

# %%
# special Plot Type
from random import sample
data = sample(range(1, 5000), 100) #membuat 100 data random dari 1 s/d 5000
plt.hist(data) #membuat histogram plot
# Out:
# (array([ 7.,  9., 15.,  4., 13., 14.,  6., 12.,  7., 13.]),
#  array([  39. ,  529.4, 1019.8, 1510.2, 2000.6, 2491. , 2981.4, 3471.8,
#         3962.2, 4452.6, 4943. ]),
#  <a list of 10 Patch objects>)
